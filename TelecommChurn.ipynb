# %% [markdown]
# <a href="https://colab.research.google.com/github/dipakpatil2001/Projects_Portfolio/blob/main/TelecommChurn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Name**            - Dipak Patil

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Telecom Churn.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
df.count()
# Out:
# State                     3333
# Account length            3333
# Area code                 3333
# International plan        3333
# Voice mail plan           3333
# Number vmail messages     3333
# Total day minutes         3333
# Total day calls           3333
# Total day charge          3333
# Total eve minutes         3333
# Total eve calls           3333
# Total eve charge          3333
# Total night minutes       3333
# Total night calls         3333
# Total night charge        3333
# Total intl minutes        3333
# Total intl calls          3333
# Total intl charge         3333
# Customer service calls    3333
# Churn                     3333
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns:
  print("number of unique values in", i, "is", df[i].nunique())
# Out:
# number of unique values in State is 51
# number of unique values in Account length is 212
# number of unique values in Area code is 3
# number of unique values in International plan is 2
# number of unique values in Voice mail plan is 2
# number of unique values in Number vmail messages is 46
# number of unique values in Total day minutes is 1667
# number of unique values in Total day calls is 119
# number of unique values in Total day charge is 1667
# number of unique values in Total eve minutes is 1611
# number of unique values in Total eve calls is 123
# number of unique values in Total eve charge is 1440
# number of unique values in Total night minutes is 1591
# number of unique values in Total night calls is 120
# number of unique values in Total night charge is 933
# number of unique values in Total intl minutes is 162
# number of unique values in Total intl calls is 21
# number of unique values in Total intl charge is 162
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
print("number of customers churning:",df[df["Churn"]==True]["Churn"].count())  # total no of customers churning

churn_df=df[df['Churn']==True]                                              # creating separate dataframe for churned customers

print("total number of unique area codes: ", df['Area code'].nunique())     # unique area codes

print("customers with international plans: ", df[df["International plan"]=="Yes"]["International plan"].count()) # total number of customer with activated international plan

print("customers with voicemail plans: ", df[df["Voice mail plan"]=="Yes"]["Voice mail plan"].count())  # total number of customer with activated voice mail plan

churn_df
# Out:
# number of customers churning: 483
# total number of unique area codes:  3
# customers with international plans:  323
# customers with voicemail plans:  922
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# ...

# %%
# percentage of customers getting churned
print(f"total number of customer: {df.Churn.count()}")
print( "Percentage of customers getting churned is:", round((churn_df.Churn.count()/df.Churn.count())*100 ,2),"%")
# Out:
# total number of customer: 3333
# Percentage of customers getting churned is: 14.49 %

# %%
#state wise customers churning
state_churn= churn_df.groupby(["State"])["Churn"].value_counts().reset_index(name="Churn Count")
state_churn
# Out:
#    State  Churn  Churn Count
# 0     AK   True            3
# 1     AL   True            8
# 2     AR   True           11
# 3     AZ   True            4
# 4     CA   True            9
# 5     CO   True            9
# 6     CT   True           12
# 7     DC   True            5
# 8     DE   True            9
# 9     FL   True            8
# 10    GA   True            8
# 11    HI   True            3
# 12    IA   True            3
# 13    ID   True            9
# 14    IL   True            5
# 15    IN   True            9
# 16    KS   True           13
# 17    KY   True            8
# 18    LA   True            4
# 19    MA   True           11
# 20    MD   True           17
# 21    ME   True           13
# 22    MI   True           16
# 23    MN   True           15
# 24    MO   True            7
# 25    MS   True           14
# 26    MT   True           14
# 27    NC   True           11
# 28    ND   True            6
# 29    NE   True            5
# 30    NH   True            9
# ...

# %%
#area wise customer count
area_count= df.groupby(["Area code"]).Churn.count()
area_count
# Out:
# Area code
# 408     838
# 415    1655
# 510     840
# Name: Churn, dtype: int64

# %%
# Area code wise churn percentage upon area specific
area_churn_S=df.groupby(["Area code"])["Churn"].mean()*100
area_churn_S
# Out:
# Area code
# 408    14.558473
# 415    14.259819
# 510    14.880952
# Name: Churn, dtype: float64

# %%
# Area code wise churn percentage upon overall
area_churn = round((churn_df.groupby(["Area code"])["Churn"].count()/df.Churn.count())*100 ,2).reset_index(name="Percentage of churn")
area_churn
# Out:
#    Area code  Percentage of churn
# 0        408                 3.66
# 1        415                 7.08
# 2        510                 3.75

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
#percentage of customers churning with or without international plan

plan_churn = (df.groupby(["International plan"])["Churn"].mean()*100 ).reset_index(name="% of churn")
plan_churn
# Out:
#   International plan  % of churn
# 0                 No   11.495017
# 1                Yes   42.414861

# %%
#day data
# percentage of people churning with average day mins, calls and charge
df.groupby(["Churn"])["Total day minutes"].mean().reset_index(name="per day minutes")
# Out:
#    Churn  per day minutes
# 0  False       175.175754
# 1   True       206.914079

# %%
df.groupby(["Churn"])["Total day calls"].mean().reset_index(name="per day calls")
# Out:
#    Churn  per day calls
# 0  False     100.283158
# 1   True     101.335404

# %%
df.groupby(["Churn"])["Total day charge"].mean().reset_index(name="per day charge")
# Out:
#    Churn  per day charge
# 0  False       29.780421
# 1   True       35.175921

# %%
#evening data
# percentage of people churning with average evening mins, calls and charge
df.groupby(["Churn"])["Total eve minutes"].mean().reset_index(name="per eve minutes")
# Out:
#    Churn  per eve minutes
# 0  False       199.043298
# 1   True       212.410145

# %%
df.groupby(["Churn"])["Total eve calls"].mean().reset_index(name="per eve calls")
# Out:
#    Churn  per eve calls
# 0  False     100.038596
# 1   True     100.561077

# %%
df.groupby(["Churn"])["Total eve charge"].mean().reset_index(name="per eve charge")
# Out:
#    Churn  per eve charge
# 0  False       16.918909
# 1   True       18.054969

# %%
#night data
# percentage of people churning with average night mins, calls and charge
df.groupby(["Churn"])["Total night minutes"].mean().reset_index(name="per night minutes")
# Out:
#    Churn  per night minutes
# 0  False         200.133193
# 1   True         205.231677

# %%
df.groupby(["Churn"])["Total night calls"].mean().reset_index(name="per night calls")
# Out:
#    Churn  per night calls
# 0  False       100.058246
# 1   True       100.399586

# %%
df.groupby(["Churn"])["Total night charge"].mean().reset_index(name="per night charge")
# Out:
#    Churn  per night charge
# 0  False          9.006074
# 1   True          9.235528

# %%
#internation call data
# percentage of people churning with average international mins, calls and charge
df.groupby(["Churn"])["Total intl minutes"].mean().reset_index(name="per international minutes")
# Out:
#    Churn  per international minutes
# 0  False                  10.158877
# 1   True                  10.700000

# %%
df.groupby(["Churn"])["Total intl calls"].mean().reset_index(name="per international calls")
# Out:
#    Churn  per international calls
# 0  False                 4.532982
# 1   True                 4.163561

# %%
df.groupby(["Churn"])["Total intl charge"].mean().reset_index(name="per international charge")
# Out:
#    Churn  per international charge
# 0  False                  2.743404
# 1   True                  2.889545

# %%
#combining day, evening, night data of calls, minutes and charge
df["Total calls"]=df.loc[:,["Total day calls","Total eve calls","Total night calls"]].sum(axis=1)
df["Total minutes"]=df.loc[:,["Total day minutes","Total eve minutes","Total night minutes"]].sum(axis=1)
df["Total charge"]=df.loc[:,["Total day charge","Total eve charge","Total night charge"]].sum(axis=1)
df.head(2)
# Out:
# (3333, 27)

# %%
#minutes per call
df["minute per call"]=df["Total minutes"]/df["Total calls"]

#charge per minute
df["charge per call"]=df["Total charge"]/df["Total minutes"]

#internation minutes per call
df["intl minute per call"]=df["Total intl minutes"]/df["Total intl calls"]

#international charge per call
df["intl charge per call"]=df["Total intl charge"]/df["Total intl calls"]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
